# %%
import geopandas as gpd 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
census_housing = gpd.read_file("./ACSDP5Y2020.DP02-2022-03-30T012451.csv")

# %%
census_housing.head()
# Out:
#                                     Label (Grouping)  \
# 0                                 HOUSEHOLDS BY TYPE
# 1                           Â Â Â Â Total households
# 2           Â Â Â Â Â Â Â Â Married-couple household
# 3  Â Â Â Â Â Â Â Â Â Â Â Â With children of the h...
# 4        Â Â Â Â Â Â Â Â Cohabiting couple household
#
#   Census Tract 1.01, Fayette County, Kentucky!!Estimate  \
# 0
# 1                                              2,048
# 2                                                205
# 3                                                (X)
# 4                                                158
#
#   Census Tract 1.01, Fayette County, Kentucky!!Margin of Error  \
# 0
# 1                                              Â±221
# 2                                               Â±70
# 3                                                (X)
# 4                                               Â±63
#
#   Census Tract 1.01, Fayette County, Kentucky!!Percent  \
# 0
# ...
