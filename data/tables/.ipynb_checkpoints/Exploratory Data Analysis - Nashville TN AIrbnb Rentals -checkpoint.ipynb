# %% [markdown]
# ## Exploratory Analysis of Airbnb and ACS Data on Housing, Nashville, TN

# %% [markdown]
# This notebook is designed to explore assets related to data from InsideAirbnb and the U.S. American Community Census Datasets.
# The primary goal of this analysis is to determine factors related to rental supply as it relates to Airbnb.

# %%
import geopandas as gpd 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
listings = gpd.read_file("./nashville_airbnb/listings.csv");

# %%
listings.head()
# Out:
#        id                                               name host_id  \
# 0    6422                                    Nashville Charm   12172
# 1   39870                              Close to Vanderbilt 2  171184
# 2   72906  Vandy/Belmont/10 mins to Broadway - Sunny 800 ...  176117
# 3  258817            ButterflyRoom-private bath- open in oct   22296
# 4  289242          MorningstarHouse, monthly room- open sept   22296
#
#         host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         Michele                        District 6  36.17315  -86.73581
# 1          Evelyn                       District 18  36.12523  -86.81278
# 2  Richard Carson                       District 18  36.13122  -86.80066
# 3           Diana                       District 12  36.16249  -86.58988
# 4           Diana                       District 12  36.16102  -86.59207
#
#          room_type price minimum_nights number_of_reviews last_review  \
# 0     Private room    40             30               674  2020-03-03
# 1     Private room    60              1               267  2021-12-04
# 2  Entire home/apt    81              2               607  2021-12-12
# 3     Private room    36             30                96  2019-12-14
# 4     Private room    34             30                76  2019-01-12
#
#   reviews_per_month calculated_host_listings_count availability_365  \
# 0              4.38                              1              199
# 1              4.17                              1              233
# 2              4.74                              1               30
# 3              0.79                              7              354
# 4              0.63                              7              354
#
#   number_of_reviews_ltm license geometry
# 0                     0             None
# 1                     5             None
# 2                     5             None
# 3                     0             None
# 4                     0             None
